# %%
import pandas as pd

# %%
pd.read_csv('tabla.csv')
# Out:
#                                                   tit  year  numauthors  \
# 0                            But Is It User Friendly?  1991           1
# 1   Computer Phobic AND Non-Phobic Individuals: Be...  1991           2
# 2   Onions, Leeks, and Garlic: Cooking Secrets of ...  1991           1
# 3                           Secrets of Silicon Valley  1994           2
# 4       Prolonged Data Deprivation: Four Case Studies  1991           1
# 5                   Silicon Valley Gastronomic Treats  1991           1
# 6                       Straight Talk About Computers  1991           1
# 7                 The Busy Executive's Database Guide  1991           2
# 8                                      Sushi, Anyone?  1991           3
# 9   Cooking with Computers: Surreptitious Balance ...  1991           2
# 10          Fifty Years in Buckingham Palace Kitchens  1991           1
# 11                                Is Anger the Enemy?  1991           2
# ...
