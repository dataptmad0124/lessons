# %% [markdown]
# # 3.1 - SQL en python
#
# ![python_sql](images/python_sql.png)
#
# **Primero cargar datos...**

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/shoes.csv')

df.head()
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3  AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4  AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
#
#          brand                                         categories  \
# 0  Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
#
#   primaryCategories                          colors                 dimension  \
# ...

# %%
# seleccion de columnas

df=df[['brand', 'colors', 'sizes', 'prices.amountMax', 'imageURLs', 'ean']]

df.head()
# Out:
#          brand                          colors  \
# 0  Naturalizer  Silver,Cream Watercolor Floral
# 1     MUK LUKS                            Grey
# 2     MUK LUKS                            Grey
# 3     MUK LUKS                           Black
# 4     MUK LUKS                            Grey
#
#                                                sizes  prices.amountMax  \
# 0  6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...             55.99
# 1                                         10,7,6,9,8             47.00
# 2                                         10,7,6,9,8             35.25
# 3                                         10,7,6,9,8             24.75
# 4                                         10,7,6,9,8             33.00
#
#                                            imageURLs           ean
# 0  https://i5.walmartimages.com/asr/861ca6cf-fa55...           NaN
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# ...

# %%
df = df.dropna().reset_index(drop=True)

df.head()
# Out:
#        brand       colors       sizes  prices.amountMax  \
# 0   MUK LUKS         Grey  10,7,6,9,8             47.00
# 1   MUK LUKS         Grey  10,7,6,9,8             35.25
# 2   MUK LUKS        Black  10,7,6,9,8             24.75
# 3   MUK LUKS         Grey  10,7,6,9,8             33.00
# 4  Soft Ones  Brown Tweed  5,6.5,9,11             14.00
#
#                                            imageURLs           ean
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 2  https://i5.walmartimages.com/asr/950d38a5-0113...  3.397705e+10
# 3  https://i5.walmartimages.com/asr/5e137bc3-c900...  3.397705e+10
# 4  https://i5.walmartimages.com/asr/7b979ba6-fa0a...  3.397705e+10

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664 entries, 0 to 663
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             664 non-null    object
#  1   colors            664 non-null    object
#  2   sizes             664 non-null    object
#  3   prices.amountMax  664 non-null    float64
#  4   imageURLs         664 non-null    object
#  5   ean               664 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 734.7 KB

# %%
codigo=pd.read_csv('../data/upc_corpus.csv')

codigo.head()
# Out:
# /var/folders/95/ms6dwls51ls1jq0t456d3r200000gn/T/ipykernel_53043/1615179648.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   codigo=pd.read_csv('../data/upc_corpus.csv')
#             ean                                               name
# 0  725177540363  Belle and The Yank 1/4" - 20 TPI x 90mm Hex Dr...
# 1  725177540370  Belle and The Yank 1/4" - 20 TPI x 120mm Hex D...
# 2  797776092321       Eazel Wines 750ml Red Wine Eazel Shiraz 2014
# 3  701197194311  IsyLei lilla IsyLei All-In-One, lilla - Cono L...
# 4  797776110773                    MsConscious 370g Skinny Granola

# %%
codigo.shape
# Out:
# (1048575, 2)

# %%
df.ean = codigo.ean.iloc[0:len(df)]

df.head()
# Out:
#        brand       colors       sizes  prices.amountMax  \
# 0   MUK LUKS         Grey  10,7,6,9,8             47.00
# 1   MUK LUKS         Grey  10,7,6,9,8             35.25
# 2   MUK LUKS        Black  10,7,6,9,8             24.75
# 3   MUK LUKS         Grey  10,7,6,9,8             33.00
# 4  Soft Ones  Brown Tweed  5,6.5,9,11             14.00
#
#                                            imageURLs           ean
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370
# 2  https://i5.walmartimages.com/asr/950d38a5-0113...  797776092321
# 3  https://i5.walmartimages.com/asr/5e137bc3-c900...  701197194311
# 4  https://i5.walmartimages.com/asr/7b979ba6-fa0a...  797776110773

# %%
df.tail()
# Out:
#            brand                                         colors  \
# 659  easy street  Turquo,Black,Yellow,Navy,Natural,Coral,Pewter
# 660  easy street  Turquo,Black,Yellow,Navy,Natural,Coral,Pewter
# 661  easy street  Turquo,Black,Yellow,Navy,Natural,Coral,Pewter
# 662  easy street  Turquo,Black,Yellow,Navy,Natural,Coral,Pewter
# 663  easy street  Turquo,Black,Yellow,Navy,Natural,Coral,Pewter
#
#                                                  sizes  prices.amountMax  \
# 659  5 MED,5.5 MED,6 MED,6.5 MED,7 MED,7.5 MED,8 ME...             54.99
# 660  5 MED,5.5 MED,6 MED,6.5 MED,7 MED,7.5 MED,8 ME...             54.99
# 661  5 MED,5.5 MED,6 MED,6.5 MED,7 MED,7.5 MED,8 ME...             54.99
# 662  5 MED,5.5 MED,6 MED,6.5 MED,7 MED,7.5 MED,8 ME...             54.99
# 663  5 MED,5.5 MED,6 MED,6.5 MED,7 MED,7.5 MED,8 ME...             54.99
#
#                                              imageURLs            ean
# 659  https://media.kohlsimg.com/is/image/kohls/2794...  8850043324647
# ...

# %%
# un registro por talla y color

# %%
df.colors = df.colors.apply(lambda x: x.split(','))

df.sizes = df.sizes.apply(lambda x: x.split(','))

# %%
df.head()
# Out:
#        brand         colors             sizes  prices.amountMax  \
# 0   MUK LUKS         [Grey]  [10, 7, 6, 9, 8]             47.00
# 1   MUK LUKS         [Grey]  [10, 7, 6, 9, 8]             35.25
# 2   MUK LUKS        [Black]  [10, 7, 6, 9, 8]             24.75
# 3   MUK LUKS         [Grey]  [10, 7, 6, 9, 8]             33.00
# 4  Soft Ones  [Brown Tweed]   [5, 6.5, 9, 11]             14.00
#
#                                            imageURLs           ean
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370
# 2  https://i5.walmartimages.com/asr/950d38a5-0113...  797776092321
# 3  https://i5.walmartimages.com/asr/5e137bc3-c900...  701197194311
# 4  https://i5.walmartimages.com/asr/7b979ba6-fa0a...  797776110773

# %%
df = df.explode('sizes').reset_index(drop=True)

df = df.explode('colors').reset_index(drop=True)

# %%
df=df.dropna().reset_index(drop=True)

df.head()
# Out:
#       brand colors sizes  prices.amountMax  \
# 0  MUK LUKS   Grey    10              47.0
# 1  MUK LUKS   Grey     7              47.0
# 2  MUK LUKS   Grey     6              47.0
# 3  MUK LUKS   Grey     9              47.0
# 4  MUK LUKS   Grey     8              47.0
#
#                                            imageURLs           ean
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363

# %%
df.columns = ['brand', 'color', 'size', 'price', 'image', 'ean']

df.head()
# Out:
#       brand color size  price  \
# 0  MUK LUKS  Grey   10   47.0
# 1  MUK LUKS  Grey    7   47.0
# 2  MUK LUKS  Grey    6   47.0
# 3  MUK LUKS  Grey    9   47.0
# 4  MUK LUKS  Grey    8   47.0
#
#                                                image           ean
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363

# %%
df['id'] = [i for i in range(len(df))]

df.head()
# Out:
#       brand color size  price  \
# 0  MUK LUKS  Grey   10   47.0
# 1  MUK LUKS  Grey    7   47.0
# 2  MUK LUKS  Grey    6   47.0
# 3  MUK LUKS  Grey    9   47.0
# 4  MUK LUKS  Grey    8   47.0
#
#                                                image           ean  id
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363   0
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363   1
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363   2
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363   3
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363   4

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41117 entries, 0 to 41116
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   brand   41117 non-null  object
#  1   color   41117 non-null  object
#  2   size    41117 non-null  object
#  3   price   41117 non-null  float64
#  4   image   41117 non-null  object
#  5   ean     41117 non-null  object
#  6   id      41117 non-null  int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 39.4 MB

# %% [markdown]
# ### SqlAlchemy

# %%
# %pip install SQLAlchemy==1.4.45

# %%
# %pip install pymysql

# %%
from sqlalchemy import create_engine

# %%
# conexion a servidor y creacion una base de datos

# string de conexion - URI

# lenguaje+driver://usuario:password@servidor:puerto


str_conn = 'mysql+pymysql://root:password@localhost:3306'

cursor = create_engine(str_conn).connect()

cursor

# %%
cursor.execute('drop database if exists apps;')

# %%
cursor.execute('create database apps;')

# %% [markdown]
# ### SQL - Pandas

# %%
# lenguaje+driver://usuario:password@servidor:puerto/database


str_conn = 'mysql+pymysql://root:password@localhost:3306/apps'

cursor = create_engine(str_conn)

# %%
df.to_sql(name='zapatos',       # nombre de la tabla
          con=cursor,           # conexion al servidor SQL
          if_exists='replace',  # si existe reemplaza, append añade
          index=False
         )
# Out:
# 41117

# %%
cursor.execute('select * from zapatos limit 1;').fetchall()
# Out:
# [('MUK LUKS', 'Grey', '10', 47.0, 'https://i5.walmartimages.com/asr/421de5d5-3a74-4ca2-ae91-a75787f7da41_1.375e3cf74dc82303ce37bdf6a9742610.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF ... (601 characters truncated) ... https://i5.walmartimages.com/asr/a486d1cf-f2b5-49ca-b0f8-3e2db896c51c_1.de1c99ac6fdfcf3dc3ddbd9c1c6c72b1.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF', '725177540363', 0)]

# %%
cursor.execute('select count(*) from zapatos;').fetchall()
# Out:
# [(41117,)]

# %%
df2 = pd.read_sql('select * from zapatos limit 3;', cursor)

df2
# Out:
#       brand color size  price  \
# 0  MUK LUKS  Grey   10   47.0
# 1  MUK LUKS  Grey    7   47.0
# 2  MUK LUKS  Grey    6   47.0
#
#                                                image           ean  id
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363   0
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363   1
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363   2

# %%
data = pd.read_csv('../data/apple_store.csv')

data.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#    price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0   3.99             21292                26          4.0              4.5
# 1   0.00            161065                26          4.0              3.5
# 2   0.00            188583              2822          3.5              4.5
# 3   0.00            262241               649          4.0              4.5
# 4   0.00            985920              5320          4.5              5.0
#
#     prime_genre
# 0         Games
# 1  Productivity
# ...

# %%
cursor.execute('select count(*) from ratings;').fetchall()
# Out:
# [(7197,)]

# %%
data.to_sql(name='ratings',   # nombre de la tabla
            con=create_engine('mysql+pymysql://root:password@localhost:3306/apps'),  # servidor
            if_exists='replace',  # añade
           index=True
           )
# Out:
# 7197

# %%
cursor.execute('select count(*) from ratings;').fetchall()
# Out:
# [(7197,)]

# %%
cursor.execute('alter table zapatos add primary key (id);')  # añade la PK a zapatos

# %%
data.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#    price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0   3.99             21292                26          4.0              4.5
# 1   0.00            161065                26          4.0              3.5
# 2   0.00            188583              2822          3.5              4.5
# 3   0.00            262241               649          4.0              4.5
# 4   0.00            985920              5320          4.5              5.0
#
#     prime_genre
# 0         Games
# 1  Productivity
# ...

# %%
query = '''

select track_name, user_rating, prime_genre

    from ratings
    
    where price=0 and user_rating>4
    
    ;


'''

# %%
query
# Out:
# '\n\nselect track_name, user_rating, prime_genre\n\n    from ratings\n    \n    where price=0 and user_rating>4\n    \n    ;\n\n\n'

# %%
pd.read_sql(query, cursor).head()
# Out:
#                             track_name  user_rating   prime_genre
# 0                                Bible          4.5     Reference
# 1                     Sonos Controller          4.5         Music
# 2  OpenTable - Restaurant Reservations          4.5  Food & Drink
# 3                        Chase Mobile℠          4.5       Finance
# 4               The Masters Tournament          4.5        Sports

# %%
query = '''

select prime_genre,
       sum(rating_count_tot) as total_rating,
       avg(user_rating) as avg_rating

    from ratings
    
    where price=0 
    
    group by prime_genre
    
    order by total_rating desc
    
    limit 10;

;
'''

# %%
df3 = pd.read_sql(query, cursor)

df3
# Out:
#          prime_genre  total_rating  avg_rating
# 0              Games    85426046.0    3.528578
# 1  Social Networking    15180364.0    2.996503
# 2      Photo & Video     9101464.0    3.793413
# 3              Music     7568592.0    3.940299
# 4      Entertainment     7229738.0    3.148204
# 5           Shopping     4536696.0    3.533058
# 6             Sports     3180378.0    2.917722
# 7          Utilities     3054202.0    3.454128
# 8   Health & Fitness     3032752.0    3.578947
# 9            Weather     2927698.0    3.258065

# %%
df3.to_sql(name='calculos',
          con=cursor)
# Out:
# 10

# %%
df3.to_sql(name='calculos',
          con=cursor,
          schema='bank')
# Out:
# 10

# %%
datos=pd.read_sql('''select *
                     
                     from ratings
                     
                     where price=0
                     
                     limit 10;''', cursor)


datos.to_sql(name='rateos', con=cursor, if_exists='replace', index=False)
# Out:
# 10

# %%
datos
# Out:
#    index         id                                         track_name  \
# 0      1  281796108                          Evernote - stay organized
# 1      2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 2      3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 3      4  282935706                                              Bible
# 4      6  283646709             PayPal - Send and request money safely
# 5      7  284035177                            Pandora - Music & Radio
# 6     12  284815942               Google – Search made just for mobile
# 7     13  284847138                   Bank of America - Mobile Banking
# 8     15  284876795             TripAdvisor Hotels Flights Restaurants
# 9     16  284882215                                           Facebook
#
#    size_bytes  price  rating_count_tot  rating_count_ver  user_rating  \
# 0   158578688    0.0            161065                26          4.0
# ...

# %%
cursor.execute('alter table ratings add primary key (id);')    # añade PK

# %%
query = 'alter table rateos add foreign key (id) references ratings (id);'

cursor.execute(query)

# %%
# password


str_conn='mysql+pymysql://root:password@localhost:3306/publications'

cursor=create_engine(str_conn).connect()

# %%
query='''
        select title, year(max(pubdate)) as 'year',
                count(titleauthor.title_id) as num_titles,
                group_concat(concat(authors.au_fname, ' ', authors.au_lname)) as authors
        
        from titles
        
        left join titleauthor
        on titles.title_id=titleauthor.title_id
        
        left join authors
        on authors.au_id=titleauthor.au_id
        
        group by titles.title
        
        order by num_titles desc;

'''

# %%
pd.read_sql(query, cursor)
# Out:
#                                                 title  year  num_titles  \
# 0                                      Sushi, Anyone?  1991           3
# 1   Computer Phobic AND Non-Phobic Individuals: Be...  1991           2
# 2   Cooking with Computers: Surreptitious Balance ...  1991           2
# 3                                 Is Anger the Enemy?  1991           2
# 4                           Secrets of Silicon Valley  1994           2
# 5                 The Busy Executive's Database Guide  1991           2
# 6                               The Gourmet Microwave  1991           2
# 7                            But Is It User Friendly?  1991           1
# 8                 Emotional Security: A New Algorithm  1991           1
# 9           Fifty Years in Buckingham Palace Kitchens  1991           1
# 10                                  Life Without Fear  1991           1
# 11                                      Net Etiquette  2014           1
# ...

# %%
# %%time

pd.read_sql('select * from employee;', cursor)['job_lvl'].count()
# Out:
# CPU times: user 5.06 ms, sys: 1.72 ms, total: 6.78 ms
# Wall time: 6.04 ms
# 43

# %%
pd.read_sql('select * from employee;', cursor).shape
# Out:
# (43, 8)

# %%
# %%time

pd.read_sql('select count(job_lvl) as j from employee;', cursor)['j'][0]
# Out:
# CPU times: user 2.93 ms, sys: 1.8 ms, total: 4.73 ms
# Wall time: 3.94 ms
# 43

# %%
pd.read_sql('select count(job_lvl) as j from employee;', cursor).shape
# Out:
# (1, 1)

# %%
# crear una vista

query='''

        create view prueba_vista as
        
        select title, year(max(pubdate)) as 'year',
                count(titleauthor.title_id) as num_titles,
                group_concat(concat(authors.au_fname, ' ', authors.au_lname)) as authors
        
        from titles
        
        left join titleauthor
        on titles.title_id=titleauthor.title_id
        
        left join authors
        on authors.au_id=titleauthor.au_id
        
        group by titles.title
        
        order by num_titles desc;

'''

cursor.execute(query)

# %%
pd.read_sql('select * from prueba_vista;', cursor)
# Out:
#                                                 title  year  num_titles  \
# 0                                      Sushi, Anyone?  1991           3
# 1   Computer Phobic AND Non-Phobic Individuals: Be...  1991           2
# 2   Cooking with Computers: Surreptitious Balance ...  1991           2
# 3                                 Is Anger the Enemy?  1991           2
# 4                           Secrets of Silicon Valley  1994           2
# 5                 The Busy Executive's Database Guide  1991           2
# 6                               The Gourmet Microwave  1991           2
# 7                            But Is It User Friendly?  1991           1
# 8                 Emotional Security: A New Algorithm  1991           1
# 9           Fifty Years in Buckingham Palace Kitchens  1991           1
# 10                                  Life Without Fear  1991           1
# 11                                      Net Etiquette  2014           1
# ...

# %%
# password


str_conn='mysql+pymysql://root:password@localhost:3306/publications'

cursor=create_engine(str_conn).connect()

# %%
with open('password.txt', 'r') as file:
    
    user, pass_ = file.read().split(',')

# %%
pass_ = pass_.strip()

# %%
str_conn=f'mysql+pymysql://{user}:{pass_}@localhost:3306/publications'

cursor=create_engine(str_conn).connect()

cursor.execute('select * from authors;')

# %%
from password import *

# %%
from password import USER, PASSWORD

# %%
str_conn=f'mysql+pymysql://{USER}:{PASSWORD}@localhost:3306/publications'

cursor=create_engine(str_conn).connect()

cursor.execute('select * from authors;')
